# %% [markdown]
# # Identifying Entities in Healthcare Data

# %% [markdown]
# Workspace set up: Import and Install useful packages.

# %%
#a pure python library for conditional random field
# !pip install pycrf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycrf in /usr/local/lib/python3.7/dist-packages (0.0.1)

# %%
#sklearn-crfsuite is thin a CRFsuite (python-crfsuite) wrapper which provides scikit-learn-compatible sklearn_crfsuite
# !pip install sklearn-crfsuite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.7/dist-packages (0.3.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (1.15.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (0.9.8)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (4.64.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite) (0.8.9)

# %%
#import Python Packages
import spacy
import sklearn_crfsuite 
from sklearn_crfsuite import metrics

# %%
# NLP Model
model = spacy.load("en_core_web_sm") #English pipeline optimized for CPU

# %%
#other Python packages
import numpy as np
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Preprocessing
# The dataset provided is in the form of one word per line. Let's understand the format of data below:
#
# Suppose there are x words in a sentence, then there will be x continuous lines with one word in each line.
# Further, the two sentences are separated by empty lines. The labels for the data follow the same format.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To decipher the given corpus which is given one word at a time in one line, and create sentences out of the, I have created this function below named unpack_given_file. This function takes the file name as input and unpacks line by line to form sentences. It returns the List of sentences to the calling module.

# %%
def unpack_given_file(file_name):
    ''' This function takes the file name as input and unpacks line by line to form sentences. It returns the List of sentences'''
    file=open(file_name,'r') # Open the file
    data=file.readlines() # Perform line by line reading
    file.close() # Close the file
    L=[];sent=[] # initialize two empty lists L is temporary to create each sentence and sent is the list of sentences returned
    for line in data:
        if line == '\n': # empty line encountered
            sent.append(" ".join(L)) # Creating a sentence
            L=[] # reset the temporary list
        else: 
            L.append(line.rstrip('\n')) # Keep adding to the temporary list
    return sent

# %%
# Train Set
train_set = unpack_given_file('/content/train_sent')

# %%
# Print Train Set Example
train_set[10:15]
# Out:
# ['A 2- , 3- , and 4-day mean temperature prior to the test date was compared to AFI using a Spearman-rank Correlation',
#  'This relationship should be taken into account when interpreting the AFI as a measure of fetal well-being',
#  'The study population included 84 women with gestational diabetes , ascertained by universal screening of all women attending the antenatal clinic of the Hadassah Medical Center , over a 2-year period',
#  "The 60 women ( 71 % ) , who initiated treatment before 34 completed weeks , composed the `` early '' group",
#  "The 24 women ( 29 % ) , who initiated treatment after the 34th week , composed the `` late '' group"]

# %%
# Train Set Label 
train_label = unpack_given_file('/content/train_label')
train_label[10:15]
# Out:
# ['O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O',
#  'O O O O O O O D D O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O']

# %%
# Test Set 
test_set = unpack_given_file('/content/test_sent')

# %%
# Print Test Set Examples
test_set[10:15]
# Out:
# ['The most common indication leading to diagnosis was abnormal ultrasound finding ( 48.2 % ) , followed by advanced maternal age ( 44.4 % )',
#  'However , 63 % of the trisomic fetuses belonged to mothers aged 35 years and above',
#  'Trisomy 18 fetuses showed hydramnios , intrauterine growth retardation , microcephaly , spina bifida , and nonimmune hydrops fetalis',
#  'The objective of this study was to determine if the rate of preeclampsia is increased in triplet as compared to twin gestations',
#  'These were matched for maternal age , parity , and race to twin gestations ( N = 53 ) from the same population']

# %%
# Test Set Labels
test_label = unpack_given_file('/content/test_label')
test_label[10:15]
# Out:
# ['O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O',
#  'D D O O O O O O O O D O D D O O D D D',
#  'O O O O O O O O O O O O D O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O']

# %%
# Combination of Train & Test Set
all_sent = train_set + test_set
len(all_sent)
# Out:
# 3655

# %% [markdown]
# Observe 3655 total sentences in the corpus

# %%
# Combination of Train & Test Set Label
all_labels = train_label + test_label
len(all_labels)
# Out:
# 3655

# %% [markdown]
# ## Similarly, observe 3655 total labels in the entire given corpus

# %%
# creating dataframe out of the given sentences and labels
df = pd.DataFrame(list(zip(all_sent,all_labels)),columns=['sentences','labels'])
df.head()
# Out:
#                                            sentences  \
# 0  All live births > or = 23 weeks at the Univers...
# 1  The total cesarean rate was 14.4 % ( 344 of 23...
# 2  Abnormal presentation was the most common indi...
# 3  The `` corrected '' cesarean rate ( maternal-f...
# 4  Arrest of dilation was the most common indicat...
#
#                                               labels
# 0  O O O O O O O O O O O O O O O O O O O O O O O ...
# 1  O O O O O O O O O O O O O O O O O O O O O O O O O
# 2                      O O O O O O O O O O O O O O O
# 3  O O O O O O O O O O O O O O O O O O O O O O O ...
# 4        O O O O O O O O O O O O O O O O O O O O O O

# %%
# Creating new columns which is the total number of O tags, D tags and T tags in a sentence/document
df['O_label'] = df.labels.apply(lambda x: len(re.findall('O',x))) # Get total number of O labels in the given sentence
df['D_label'] = df.labels.apply(lambda x: len(re.findall('D',x))) # Get total number of D labels in the given sentence
df['T_label'] = df.labels.apply(lambda x: len(re.findall('T',x))) # Get total number of T labels in the given sentence

df.tail(15)
# Out:
#                                               sentences  \
# 3640  Efficacy of open-bite treatment with the Thera...
# 3641  Hepatic arterial infusion of chemotherapy afte...
# 3642  Evidence for double resistance to permethrin a...
# 3643  Urgent colonoscopy for the diagnosis and treat...
# 3644  Effects of tolcapone , a catechol-O-methyltran...
# 3645  Dry powdered formoterol , twice a day versus a...
# 3646                            Celecoxib for arthritis
# 3647  Poliomyelitis prevention : revised recommendat...
# 3648  Brimonidine tartrate 0.2 % twice daily vs timo...
# 3649  Epoetin : a pharmacoeconomic review of its use...
# 3650  Reduction of vasoreactivity and thrombogenicit...
# 3651  Effects of ultrasound energy on total peripher...
# 3652  High-dose chemotherapy with autologous stem-ce...
# 3653  `` Tandem '' high-dose chemoradiotherapy with ...
# 3654  Intravenous immune globulin for recurrent spon...
#
#                                            labels  O_label  D_label  T_label
# 3640                                O O D O O O T        5        1        1
# 3641                    O O O O T O T O D D O D D        7        4        2
# 3642                        O O O O O T T T O D D        6        2        3
# 3643                        O T O O O O O O D D D        7        3        1
# 3644  O O T T T T T O O O O O O O T O O O D D D O       13        3        6
# 3645    T T T O O O O O T T O O O O O O O O O D D       14        2        5
# 3646                                        T O D        1        1        1
# 3647                  D O O O O O O O O O O O D T       11        2        1
# 3648          T T O O O O O T O O O O O O O O D O       14        1        3
# 3649        T O O O O O O O O D D D O O O O O O O       15        3        1
# 3650                    O O D O D O T T O O O T T        7        2        4
# 3651              O O T T O D D D D O O O O O O O       10        4        2
# 3652                          T T T T T T O D D D        1        3        6
# 3653        T T T T T T T T T O O O O O O O O D D        8        2        9
# 3654                                T T T O D D D        1        3        3

# %% [markdown]
# # Exploratory data analysis EDA

# %%
#EDA
df.describe()
# Out:
#            O_label      D_label      T_label
# count  3655.000000  3655.000000  3655.000000
# mean     15.269494     1.337620     1.045417
# std      12.396386     2.109442     2.377397
# min       0.000000     0.000000     0.000000
# 25%       6.000000     0.000000     0.000000
# 50%      12.000000     0.000000     0.000000
# 75%      21.000000     2.000000     1.000000
# max     125.000000    34.000000    30.000000

# %% [markdown]
# ### We observe here that the number of D labels at 50% quantile is 0 which indicates that less than half of the given corpus have the D labels and even lesser corpus have T labels. Note that even T labels are 0 at 50% quantile.

# %%
# shape of DataFrame
df.shape
# Out:
# (3655, 5)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3655 entries, 0 to 3654
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentences  3655 non-null   object
#  1   labels     3655 non-null   object
#  2   O_label    3655 non-null   int64
#  3   D_label    3655 non-null   int64
#  4   T_label    3655 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 142.9+ KB

# %%
df[df.T_label>25]
# Out:
#                                               sentences  \
# 2037  only the combination of a cell wall-active ant...
# 2090  objective : to examine the effectiveness of ni...
# 2315  A three-step treatment algorithm for refractor...
#
#                                                  labels  O_label  D_label  \
# 2037  O O T T T T T T T T T T T T T T T T T T T T T ...       21        9
# 2090  O O O O O O O T T T T T T T T T T T T T T T T ...        9        2
# 2315  O O O O O D D O O T T T T T T T T T T T T T T ...       22        2
#
#       T_label
# 2037       30
# 2090       28
# 2315       28

# %%
df.T_label.sum()
# Out:
# 3821

# %%
df.O_label.sum()
# Out:
# 55810

# %%
df.D_label.sum()
# Out:
# 4889

# %%
# Data Frame having D & T count as zero
df[(df.T_label==0) &(df.D_label==0)]
# Out:
#                                               sentences  \
# 0     All live births > or = 23 weeks at the Univers...
# 1     The total cesarean rate was 14.4 % ( 344 of 23...
# 2     Abnormal presentation was the most common indi...
# 3     The `` corrected '' cesarean rate ( maternal-f...
# 4     Arrest of dilation was the most common indicat...
# ...                                                 ...
# 3410  Relatives in the resuscitation room : their po...
# 3412  Subcutaneous autologous ovarian transplantatio...
# 3417              Adolescent pregnancy and sexual abuse
# 3418  Still hard to know how large the benefits will...
# 3554  < TO_SEE > CONCLUSION : Direct PTA may be perf...
#
#                                                  labels  O_label  D_label  \
# 0     O O O O O O O O O O O O O O O O O O O O O O O ...       45        0
# 1     O O O O O O O O O O O O O O O O O O O O O O O O O       25        0
# 2                         O O O O O O O O O O O O O O O       15        0
# 3     O O O O O O O O O O O O O O O O O O O O O O O ...       38        0
# 4           O O O O O O O O O O O O O O O O O O O O O O       22        0
# ...                                                 ...      ...      ...
# 3410                                O O O O O O O O O O       10        0
# 3412                                O O O O O O O O O O       10        0
# 3417                                          O O O O O        5        0
# 3418                              O O O O O O O O O O O       11        0
# 3554  O O O O O O O O O O O O O O O O O O O O O O O ...       52        0
#
#       T_label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 3410        0
# 3412        0
# 3417        0
# 3418        0
# 3554        0
#
# [1843 rows x 5 columns]

# %% [markdown]
# ### Conclusion : Total of 1843 rows in the total sentences has only O (Others) tags.

# %%
plt.figure(figsize=(20,16))
plt.subplot(2,3,1)
plt.title('Distribution of O Label')
sns.boxplot(df.O_label)
plt.subplot(2,3,2)
plt.title('Distribution of D Label')
sns.boxplot(df.D_label)
plt.subplot(2,3,3)
plt.title('Distribution of T Label')
sns.boxplot(df.T_label)
plt.show()

# %% [markdown]
# #During the EDA we can observe that per sentence, the distribution of the O label is above 120 in some sentences while its overall range of its values lie around 0 to 40.
#
# #We also observe that there are comparatively few sentences that has D labels and even lesser of T labels.
#
# #This observation can also be verifed in the describe function of the labels.

# %% [markdown]
# ### Count the number of sentences in the processed train and test dataset

# %%
print('Number of sentence in train set',len(train_set))
print('Number of sentence in test set',len(test_set))
# Out:
# Number of sentence in train set 2599
# Number of sentence in test set 1056

# %% [markdown]
# ### Count the number of lines of labels in the processed train and test dataset.

# %%
print('Number of labels in train set',len(train_label))
print('Number of labels in test set',len(test_label))
# Out:
# Number of labels in train set 2599
# Number of labels in test set 1056

# %% [markdown]
# # PoS Tagging : Extract those tokens which have NOUN or PROPN as their PoS tag and find their frequency

# %%
noun_or_propn = []
for review in all_sent:
  doc = model(review)
  for token in doc:
    if token.pos_ =='NOUN' or token.pos_ =='PROPN': # only Noun & PROPN
      noun_or_propn.append(token.lemma_.lower())

# %% [markdown]
# ### Top 25 most common tokens with NOUN or PROPN PoS tags

# %%
pd.Series(noun_or_propn).value_counts().head(25)
# Out:
# patient         570
# treatment       316
# %               247
# study           234
# cancer          226
# cell            203
# therapy         182
# effect          181
# disease         170
# group           145
# case            132
# lung            120
# gene            111
# result          109
# year            105
# rate            103
# chemotherapy     91
# use              90
# trial            90
# conclusion       89
# woman            89
# analysis         86
# protein          82
# response         81
# risk             78
# dtype: int64

# %% [markdown]
# ### Here we can observe the top 25 noun and proper nouns. This indicates that the data is of a study about cancer, effects (226 Count ) , therapy (182 Count), case study, lung (120 Count). We can observe 91 counts of chemotherapy.

# %%
dict_of_words = pd.Series(noun_or_propn).value_counts().to_dict()
dict_of_words
# Out:
# {'patient': 570,
#  'treatment': 316,
#  '%': 247,
#  'study': 234,
#  'cancer': 226,
#  'cell': 203,
#  'therapy': 182,
#  'effect': 181,
#  'disease': 170,
#  'group': 145,
#  'case': 132,
#  'lung': 120,
#  'gene': 111,
#  'result': 109,
#  'year': 105,
#  'rate': 103,
#  'chemotherapy': 91,
#  'use': 90,
#  'trial': 90,
#  'conclusion': 89,
#  'woman': 89,
#  'analysis': 86,
#  'protein': 82,
#  'response': 81,
#  'risk': 78,
#  'child': 77,
#  'mutation': 75,
#  'drug': 74,
#  'tumor': 74,
#  'surgery': 73,
#  'method': 70,
#  'control': 70,
#  'p': 70,
#  'infection': 68,
#  'survival': 67,
#  'factor': 66,
#  'day': 63,
#  'combination': 62,
#  'evidence': 62,
#  'health': 61,
#  'term': 61,
#  'age': 61,
#  'syndrome': 60,
#  'activity': 60,
#  'acid': 59,
#  'dose': 59,
#  'care': 56,
#  'management': 56,
#  'stage': 55,
#  'c': 54,
#  'carcinoma': 54,
#  'datum': 54,
#  'month': 54,
#  'time': 52,
#  'diagnosis': 52,
#  'bone': 52,
#  'role': 50,
#  'outcome': 49,
#  'week': 48,
#  'mg': 48,
#  'b': 46,
#  'pregnancy': 46,
#  'blood': 46,
#  'practice': 45,
#  'heart': 45,
#  'family': 45,
#  'system': 44,
#  'to_see': 43,
#  'medicine': 43,
#  'level': 43,
#  'report': 42,
#  'vaccine': 42,
#  'growth': 42,
#  'type': 42,
#  'adult': 41,
#  'receptor': 41,
#  'model': 40,
#  'failure': 40,
#  'background': 40,
#  'comparison': 39,
#  'difference': 39,
#  'agent': 39,
#  'placebo': 38,
#  '#': 38,
#  'population': 37,
#  'hospital': 37,
#  'hepatitis': 37,
#  'tissue': 37,
#  'research': 37,
#  'infarction': 36,
#  'change': 36,
#  'region': 36,
#  'value': 36,
#  'phase': 35,
#  'resection': 35,
#  'test': 35,
#  'efficacy': 35,
#  'function': 35,
#  'mouse': 35,
#  'disorder': 34,
#  'site': 34,
#  'g': 34,
#  'association': 34,
#  'metastasis': 34,
#  'radiotherapy': 33,
#  'complication': 33,
#  'asthma': 33,
#  'calcium': 33,
#  'brain': 32,
#  'nsclc': 32,
#  'sequence': 32,
#  'diabetes': 32,
#  'antibody': 31,
#  'evaluation': 31,
#  'administration': 31,
#  'symptom': 30,
#  'prevention': 30,
#  'incidence': 30,
#  'pain': 30,
#  'period': 30,
#  'increase': 30,
#  'breast': 30,
#  'infant': 30,
#  'radiation': 29,
#  'nurse': 29,
#  'hiv': 29,
#  'review': 29,
#  'vitamin': 29,
#  'expression': 29,
#  'form': 29,
#  'alpha': 29,
#  'serum': 28,
#  'effectiveness': 28,
#  'concentration': 28,
#  'process': 28,
#  'cisplatin': 28,
#  'reaction': 28,
#  'death': 28,
#  'a': 28,
#  'irradiation': 28,
#  'exercise': 28,
#  'prostate': 27,
#  'development': 27,
#  'procedure': 27,
#  'problem': 27,
#  'man': 27,
#  'muscle': 27,
#  'activation': 27,
#  'adolescent': 26,
#  'virus': 26,
#  's': 26,
#  'h': 26,
#  'body': 26,
#  'interferon': 26,
#  'marker': 26,
#  'aspirin': 26,
#  'methods': 26,
#  'dna': 25,
#  'weight': 25,
#  'strategy': 25,
#  'life': 25,
#  'event': 25,
#  'hypertension': 25,
#  'injury': 25,
#  'plasma': 25,
#  'finding': 24,
#  'assessment': 24,
#  'chromosome': 24,
#  't': 24,
#  'delivery': 24,
#  'subject': 24,
#  'hormone': 24,
#  'lesion': 23,
#  'surface': 23,
#  'repair': 23,
#  'testing': 23,
#  'approach': 23,
#  'safety': 23,
#  'susceptibility': 23,
#  'lymphoma': 23,
#  'purpose': 23,
#  'influenza': 22,
#  'mortality': 22,
#  'kinase': 22,
#  'medium': 22,
#  'sample': 22,
#  'improvement': 22,
#  'grade': 22,
#  'resonance': 22,
#  'measurement': 21,
#  'preeclampsia': 21,
#  'loss': 21,
#  'antibiotic': 21,
#  'characteristic': 21,
#  'pylori': 21,
#  'frequency': 20,
#  'pressure': 20,
#  'prevalence': 20,
#  'min': 20,
#  'correlation': 20,
#  'inhibitor': 20,
#  'detection': 20,
#  'artery': 20,
#  'rat': 20,
#  'technique': 20,
#  'number': 20,
#  'structure': 20,
#  'cause': 19,
#  'density': 19,
#  'ii': 19,
#  'microg': 19,
#  'mechanism': 19,
#  'sperm': 19,
#  'experience': 19,
#  'line': 19,
#  'investigation': 19,
#  'percent': 19,
#  'infusion': 19,
#  'product': 19,
#  '-': 19,
#  'recovery': 19,
#  'injection': 19,
#  'mm': 19,
#  'signal': 19,
#  'objective': 18,
#  'application': 18,
#  'relationship': 18,
#  'd': 18,
#  'duration': 18,
#  'induction': 18,
#  'membrane': 18,
#  'exposure': 18,
#  'onset': 18,
#  'condition': 18,
#  'intervention': 17,
#  'part': 17,
#  'sarcoma': 17,
#  'status': 17,
#  'transplantation': 17,
#  'interval': 17,
#  'fenfluramine': 17,
#  'information': 17,
#  'quality': 17,
#  'area': 17,
#  'point': 17,
#  'presence': 17,
#  'score': 17,
#  'survey': 17,
#  'physician': 17,
#  'class': 17,
#  'online': 17,
#  'co2': 17,
#  'angioplasty': 16,
#  'assay': 16,
#  'stress': 16,
#  'community': 16,
#  'design': 16,
#  'toxicity': 16,
#  'urine': 16,
#  'formation': 16,
#  'addition': 16,
#  'head': 16,
#  'author': 16,
#  'sclc': 16,
#  'benefit': 16,
#  'feature': 16,
#  'parameter': 16,
#  'stroke': 16,
#  'dioxin': 16,
#  'index': 16,
#  'protease': 15,
#  'aids': 15,
#  'origin': 15,
#  'liver': 15,
#  'support': 15,
#  'lactate': 15,
#  'human': 15,
#  'proceeding': 15,
#  'iii': 15,
#  'cold': 15,
#  'beta': 15,
#  'neck': 15,
#  'thoracic': 14,
#  'literature': 14,
#  'paclitaxel': 14,
#  'program': 14,
#  'carboplatin': 14,
#  'importance': 14,
#  'international': 14,
#  'csf': 14,
#  'sensitivity': 14,
#  'training': 14,
#  'hodgkin': 14,
#  'american': 14,
#  'course': 14,
#  'emergency': 14,
#  'article': 14,
#  'stem': 14,
#  'potential': 14,
#  'locus': 14,
#  'criterion': 14,
#  'throat': 14,
#  'h.': 14,
#  'solution': 14,
#  'exon': 14,
#  'reduction': 14,
#  'cost': 14,
#  'melanoma': 14,
#  'defect': 14,
#  'ml': 14,
#  'steroid': 14,
#  'insulin': 14,
#  'mass': 14,
#  'issue': 14,
#  'shock': 14,
#  'regimen': 13,
#  'resolution': 13,
#  'ulcer': 13,
#  'rupture': 13,
#  'conference': 13,
#  'specie': 13,
#  'follow': 13,
#  'involvement': 13,
#  'absence': 13,
#  'heparin': 13,
#  'fetus': 13,
#  'methylphenidate': 13,
#  'examination': 13,
#  'behavior': 13,
#  'performance': 13,
#  'threshold': 13,
#  'department': 13,
#  'history': 13,
#  'metabolism': 13,
#  'l.': 13,
#  'polymorphism': 13,
#  'oxygen': 13,
#  'nerve': 13,
#  'side': 13,
#  'screening': 13,
#  'bolus': 12,
#  'society': 12,
#  'genotype': 12,
#  '=': 12,
#  'illness': 12,
#  'apoptosis': 12,
#  'insemination': 12,
#  'hemorrhage': 12,
#  'helicobacter': 12,
#  'center': 12,
#  'confidentiality': 12,
#  'fat': 12,
#  'leukemia': 12,
#  'retinoblastoma': 12,
#  'antigen': 12,
#  'hearing': 12,
#  'ms': 12,
#  'biosensor': 12,
#  'animal': 12,
#  'interest': 12,
#  'member': 12,
#  'parkinson': 12,
#  'morbidity': 12,
#  'meningitis': 12,
#  'damage': 12,
#  'oocyte': 12,
#  'rehabilitation': 12,
#  'al': 12,
#  'ratio': 12,
#  'catheter': 12,
#  'resistance': 12,
#  'stenosis': 12,
#  'kinetic': 12,
#  'l': 11,
#  'peroxynitrite': 11,
#  'state': 11,
#  'tuberculosis': 11,
#  'intensity': 11,
#  'production': 11,
#  'eye': 11,
#  'pathway': 11,
#  'dynamic': 11,
#  'recurrence': 11,
#  'rabbit': 11,
#  'language': 11,
#  'dysfunction': 11,
#  'scale': 11,
#  'volume': 11,
#  'cleavage': 11,
#  'pcr': 11,
#  'interaction': 11,
#  'pai-1': 11,
#  'usa': 11,
#  'angle': 11,
#  'warfarin': 11,
#  'foot': 11,
#  'ad': 11,
#  'fluorouracil': 11,
#  'mineral': 11,
#  'range': 11,
#  'confidence': 11,
#  'clinic': 11,
#  'protocol': 11,
#  'record': 11,
#  'childhood': 11,
#  'cocaine': 11,
#  'influence': 11,
#  'needle': 11,
#  'basis': 11,
#  'aspect': 11,
#  'sclerosis': 11,
#  'm2': 11,
#  'laser': 11,
#  'p53': 11,
#  'food': 11,
#  'culture': 11,
#  'screen': 11,
#  'athlete': 11,
#  'identification': 11,
#  'stent': 11,
#  'suppression': 11,
#  'temperature': 11,
#  'component': 10,
#  'relation': 10,
#  'wave': 10,
#  'sodium': 10,
#  'order': 10,
#  'base': 10,
#  'e': 10,
#  'ng': 10,
#  'vivo': 10,
#  'dsb': 10,
#  'ability': 10,
#  'measures': 10,
#  'up': 10,
#  'seizure': 10,
#  'choice': 10,
#  'synthetase': 10,
#  'replacement': 10,
#  'binding': 10,
#  'vein': 10,
#  'arthritis': 10,
#  'p1': 10,
#  'x': 10,
#  'regression': 10,
#  'maintenance': 10,
#  'intake': 10,
#  'sex': 10,
#  'chemical': 10,
#  'effusion': 10,
#  'significance': 10,
#  'retinopathy': 10,
#  'specificity': 10,
#  'malformation': 10,
#  'composition': 10,
#  'example': 10,
#  'source': 10,
#  'donor': 10,
#  'alteplase': 10,
#  'cure': 10,
#  'fatty': 10,
#  'enzyme': 10,
#  'cdna': 10,
#  'supplementation': 10,
#  'ultrasound': 10,
#  'world': 10,
#  'observation': 10,
#  'host': 10,
#  'organization': 10,
#  'substrate': 10,
#  'imaging': 10,
#  'corticosteroid': 10,
#  'person': 10,
#  'cycle': 10,
#  'chain': 10,
#  'wall': 10,
#  'sign': 10,
#  'vaccination': 10,
#  'gestation': 9,
#  'incontinence': 9,
#  '.': 9,
#  'domain': 9,
#  'gag': 9,
#  'amino': 9,
#  'diet': 9,
#  'antagonist': 9,
#  'material': 9,
#  'alternative': 9,
#  'presentation': 9,
#  'biology': 9,
#  'future': 9,
#  'alfa-2a': 9,
#  'gamma': 9,
#  'tumour': 9,
#  'ffa': 9,
#  'alzheimer': 9,
#  'student': 9,
#  'f': 9,
#  'hypothesis': 9,
#  'doctor': 9,
#  'angina': 9,
#  'monotherapy': 9,
#  'bypass': 9,
#  'transport': 9,
#  'd3': 9,
#  'guideline': 9,
#  'wound': 9,
#  'room': 9,
#  'node': 9,
#  'oxaliplatin': 9,
#  'amifostine': 9,
#  'classification': 9,
#  'n': 9,
#  'device': 9,
#  'modality': 9,
#  'birth': 9,
#  '+': 9,
#  'hour': 9,
#  'skin': 9,
#  'amoxicillin': 9,
#  'knowledge': 9,
#  'brca1': 9,
#  'centre': 9,
#  'property': 9,
#  'action': 9,
#  'gemcitabine': 9,
#  'penicillin': 9,
#  'generation': 9,
#  'repeat': 9,
#  'abnormality': 9,
#  'recommendation': 9,
#  'pneumonia': 9,
#  'v': 9,
#  'fibre': 9,
#  'return': 9,
#  'i': 9,
#  'hg': 9,
#  'attention': 9,
#  'deficit': 9,
#  'position': 9,
#  'fluoride': 9,
#  'arthrodesis': 9,
#  'accident': 9,
#  'national': 9,
#  'refractory': 9,
#  'chicken': 9,
#  'interview': 9,
#  'female': 9,
#  'synthesis': 9,
#  'germ': 8,
#  'stimulation': 8,
#  'psoriasis': 8,
#  'understanding': 8,
#  'energy': 8,
#  'mcv': 8,
#  'amyloidosis': 8,
#  'challenge': 8,
#  'ribavirin': 8,
#  'epilepsy': 8,
#  'united': 8,
#  'partner': 8,
#  'aim': 8,
#  'panel': 8,
#  'secretion': 8,
#  'university': 8,
#  'pibf': 8,
#  'valve': 8,
#  'setting': 8,
#  'determination': 8,
#  'impact': 8,
#  'phentermine': 8,
#  'perspective': 8,
#  'promoter': 8,
#  'recombinase': 8,
#  'cholecystectomy': 8,
#  'malignancy': 8,
#  'country': 8,
#  'hernia': 8,
#  'plate': 8,
#  'measure': 8,
#  'characterization': 8,
#  'correction': 8,
#  'biopsy': 8,
#  'depression': 8,
#  'transcription': 8,
#  'darier': 8,
#  'loci': 8,
#  'total': 8,
#  'amount': 8,
#  'drainage': 8,
#  'oil': 8,
#  'r': 8,
#  'molecule': 8,
#  'delay': 8,
#  'neuroendocrine': 8,
#  'occlusion': 8,
#  'deficiency': 8,
#  'removal': 8,
#  'preparation': 8,
#  'kidney': 8,
#  'lifestyle': 8,
#  'variant': 8,
#  'operation': 8,
#  'block': 8,
#  'strain': 8,
#  'immunoglobulin': 8,
#  'embolism': 8,
#  'agonist': 8,
#  'af-4': 8,
#  'field': 8,
#  'y': 8,
#  'rep': 8,
#  'bladder': 8,
#  'et': 8,
#  'concern': 8,
#  'analyte': 8,
#  'platelet': 8,
#  'cidofovir': 8,
#  'stone': 8,
#  'profile': 8,
#  'reference': 8,
#  'clinical': 8,
#  'meeting': 8,
#  'ems': 7,
#  'ion': 7,
#  'degree': 7,
#  'tool': 7,
#  'oncology': 7,
#  'enantiomer': 7,
#  'strength': 7,
#  'echocardiography': 7,
#  'service': 7,
#  'substance': 7,
#  'remission': 7,
#  'size': 7,
#  'analgesia': 7,
#  'ear': 7,
#  'platinum': 7,
#  'selection': 7,
#  'contrast': 7,
#  'marrow': 7,
#  'ropinirole': 7,
#  'medication': 7,
#  'relief': 7,
#  'bcr': 7,
#  'colony': 7,
#  'percentage': 7,
#  'adenocarcinoma': 7,
#  'need': 7,
#  'cataract': 7,
#  'chance': 7,
#  'determinant': 7,
#  'regulation': 7,
#  'fish': 7,
#  'availability': 7,
#  'ifosfamide': 7,
#  'length': 7,
#  'glutamine': 7,
#  'urinalysis': 7,
#  'motor': 7,
#  'colon': 7,
#  'manifesto': 7,
#  'occurrence': 7,
#  'analog': 7,
#  'main': 7,
#  'torsion': 7,
#  'series': 7,
#  'data': 7,
#  'pair': 7,
#  'success': 7,
#  'amyloid': 7,
#  'p7': 7,
#  'context': 7,
#  'fever': 7,
#  'labor': 7,
#  'hematoma': 7,
#  'absorption': 7,
#  'ventilation': 7,
#  'college': 7,
#  'pathogen': 7,
#  'cord': 7,
#  'standard': 7,
#  'celiotomy': 7,
#  'electron': 7,
#  'abscess': 7,
#  'layer': 7,
#  'allele': 7,
#  'toxin': 7,
#  'implantation': 7,
#  'lymph': 7,
#  'transmission': 7,
#  'alcohol': 7,
#  'hyperplasia': 7,
#  'dosage': 7,
#  'prescription': 7,
#  'monitoring': 7,
#  'meta': 7,
#  'cpd': 7,
#  'propionate': 7,
#  'step': 7,
#  'search': 7,
#  'spermatozoon': 7,
#  'consultation': 7,
#  'cyclin': 7,
#  'variation': 7,
#  'task': 7,
#  'capsule': 7,
#  'discharge': 7,
#  'distribution': 7,
#  'haplotype': 7,
#  'hiv-1': 7,
#  'tss': 7,
#  'bowel': 7,
#  'staging': 7,
#  'variety': 7,
#  'anomaly': 7,
#  'chlamydia': 7,
#  'pattern': 7,
#  'blockade': 7,
#  'introduction': 7,
#  'decrease': 7,
#  'afi': 7,
#  'ghb': 7,
#  'hmgi': 7,
#  'new': 7,
#  'nursing': 7,
#  'recombination': 7,
#  'september': 7,
#  'switch': 7,
#  'triplet': 7,
#  'anesthesia': 7,
#  'consideration': 7,
#  'abstract': 7,
#  'japan': 7,
#  'implication': 6,
#  'icsi': 6,
#  'medical': 6,
#  'basal': 6,
#  'contribution': 6,
#  'cent': 6,
#  'italy': 6,
#  'note': 6,
#  'trachomatis': 6,
#  'home': 6,
#  'limb': 6,
#  'preterm': 6,
#  'gastrectomy': 6,
#  'teratoma': 6,
#  'overtraining': 6,
#  'indication': 6,
#  'states': 6,
#  'arrest': 6,
#  'trigger': 6,
#  'admission': 6,
#  'male': 6,
#  'teoae': 6,
#  'subgroup': 6,
#  'predictor': 6,
#  'user': 6,
#  'compound': 6,
#  'august': 6,
#  'mean': 6,
#  'iv': 6,
#  'end': 6,
#  'peptide': 6,
#  'mellitus': 6,
#  'trisomy': 6,
#  'output': 6,
#  'rheumatoid': 6,
#  'audit': 6,
#  'thyroid': 6,
#  'deafness': 6,
#  'charge': 6,
#  'dye': 6,
#  'situ': 6,
#  'immunotherapy': 6,
#  'sera': 6,
#  'fusion': 6,
#  'insertion': 6,
#  'complex': 6,
#  'people': 6,
#  'parotid': 6,
#  'gland': 6,
#  'stability': 6,
#  'reflux': 6,
#  'thrombosis': 6,
#  'relapse': 6,
#  'cloning': 6,
#  'tract': 6,
#  'questionnaire': 6,
#  'dialysis': 6,
#  'individual': 6,
#  'pollution': 6,
#  'igg': 6,
#  'ens': 6,
#  'alteration': 6,
#  'participant': 6,
#  'peak': 6,
#  'linkage': 6,
#  'memory': 6,
#  'subset': 6,
#  'working': 6,
#  'dog': 6,
#  'neurotoxicity': 6,
#  'stimulus': 6,
#  'perception': 6,
#  'extraction': 6,
#  'coefficient': 6,
#  'prosthesis': 6,
#  'beam': 6,
#  'intron': 6,
#  'tobacco': 6,
#  'protection': 6,
#  'abuse': 6,
#  'direction': 6,
#  'manifestation': 6,
#  'december': 6,
#  'gunshot': 6,
#  'word': 6,
#  'episode': 6,
#  'heterogeneity': 6,
#  'opioid': 6,
#  'smoking': 6,
#  'reconstruction': 6,
#  'carbohydrate': 6,
#  'vas': 6,
#  'attitude': 6,
#  'kg': 6,
#  'pt': 6,
#  'fluticasone': 6,
#  'decline': 6,
#  'bleeding': 6,
#  'vitrectomy': 6,
#  'uft': 6,
#  'nmr': 6,
#  'list': 6,
#  'prescribing': 6,
#  'black': 6,
#  'lavage': 6,
#  'dpl': 6,
#  'spectroscopy': 6,
#  'odd': 6,
#  'pm': 6,
#  'abdomen': 6,
#  'technology': 6,
#  'organ': 6,
#  'set': 6,
#  'consequence': 6,
#  'tacrolimus': 6,
#  'silicone': 6,
#  'arthroplasty': 6,
#  'isolation': 6,
#  'march': 6,
#  'arabidopsis': 6,
#  'irinotecan': 6,
#  'possibility': 6,
#  'carbon': 6,
#  'mmol': 6,
#  'fibrillation': 6,
#  'palliation': 6,
#  'aed': 6,
#  'crohn': 6,
#  'guide': 6,
#  'committee': 6,
#  'extent': 5,
#  'glucose': 5,
#  'inflammation': 5,
#  'limitation': 5,
#  'wbrt': 5,
#  'gks': 5,
#  'decision': 5,
#  'radiosurgery': 5,
#  'object': 5,
#  'fracture': 5,
#  'proliferation': 5,
#  'comment': 5,
#  'lozenge': 5,
#  'accumulation': 5,
#  'zinc': 5,
#  'evolution': 5,
#  'industry': 5,
#  'rest': 5,
#  'trauma': 5,
#  'instrument': 5,
#  'tqr': 5,
#  'immunodeficiency': 5,
#  'replication': 5,
#  'gastritis': 5,
#  'raf-1': 5,
#  'map': 5,
#  'neutropenia': 5,
#  'distinction': 5,
#  'science': 5,
#  'estimate': 5,
#  'phenomenon': 5,
#  'fluid': 5,
#  'suspension': 5,
#  'pancreatitis': 5,
#  'symposium': 5,
#  'triglyceride': 5,
#  '2d': 5,
#  'nitrogen': 5,
#  'sd': 5,
#  'concept': 5,
#  'outpatient': 5,
#  'immunogenicity': 5,
#  'mutant': 5,
#  'pima': 5,
#  'indians': 5,
#  'section': 5,
#  'environment': 5,
#  'electrolyte': 5,
#  'primer': 5,
#  'methotrexate': 5,
#  'initiation': 5,
#  'oh': 5,
#  'dnase': 5,
#  'prophylaxis': 5,
#  'completion': 5,
#  'infancy': 5,
#  'monoclonal': 5,
#  'inhalation': 5,
#  'decomposition': 5,
#  'channel': 5,
#  'face': 5,
#  'option': 5,
#  'transduction': 5,
#  'placement': 5,
#  'immunization': 5,
#  'cyclophosphamide': 5,
#  'light': 5,
#  'recording': 5,
#  'mesothelioma': 5,
#  'prl': 5,
#  'translocation': 5,
#  'd1': 5,
#  'minute': 5,
#  'tese': 5,
#  'aureus': 5,
#  'living': 5,
#  'advantage': 5,
#  'eradication': 5,
#  'africa': 5,
#  'fistula': 5,
#  'revascularization': 5,
#  'third': 5,
#  'schizophrenia': 5,
#  'satisfaction': 5,
#  'transfer': 5,
#  'joint': 5,
#  'mouth': 5,
#  'tefna': 5,
#  'graft': 5,
#  'amplification': 5,
#  'chest': 5,
#  'aspiration': 5,
#  'disability': 5,
#  'way': 5,
#  'institution': 5,
#  'hyperammonemia': 5,
#  'capture': 5,
#  'drosophila': 5,
#  'osmolarity': 5,
#  'photopheresis': 5,
#  'cortisol': 5,
#  'assurance': 5,
#  'education': 5,
#  'mitogen': 5,
#  'poisoning': 5,
#  'carrier': 5,
#  'leukocyte': 5,
#  'res': 5,
#  'homini': 5,
#  'pc': 5,
#  'question': 5,
#  'dimension': 5,
#  'video': 5,
#  'acute': 5,
#  'airway': 5,
#  'dislocation': 5,
#  'willingness': 5,
#  'ligand': 5,
#  'yag': 5,
#  'pack': 5,
#  'prognosis': 5,
#  'mspi': 5,
#  'inhibition': 5,
#  'igf-1': 5,
#  'gstm1': 5,
#  'flow': 5,
#  'turnover': 5,
#  'award': 5,
#  'ct': 5,
#  'microsatellite': 5,
#  'mrs': 5,
#  'lobe': 5,
#  'london': 5,
#  'name': 5,
#  'gradient': 5,
#  'picture': 5,
#  ...}

# %%
len(noun_or_propn)
# Out:
# 24292

# %% [markdown]
# # As we can see we have 24,292 words found that has parts of speech (PoS) tag of nouns or proper nouns from our model
#
# ## Defining features for CRF
#
# ## Computing Features using the following features for our input sequences.
#
# ## We have defined the following features for CRF model building:
# > f1=postag of the word
#
# > f2=word in lower case
#
# > f3=last 3 characters of the word
#
# > f4=last 2 characters of the word
#
# > f5=1; if the word is in uppercase, otherwise 0
#
# > f6=1; if word is a number; otherwise 0
#
# > f7=1; if the word starts with a capital letter, otherwise 0
#
# > If the given word is not the beginning of the sentence, we include the features of the previous word too
#
# > If the word is at the beginning of sentence we mark it as 'BEG'
#
# > If the word is at the end of the sentence we mark it as 'END'

# %%
# Let's define the features to get the feature value for one word.
def getFeaturesForOneWord(sentence, pos):
  word=sentence[pos]
  for token in model(word):
    word_pos_tag=token.pos_
  features=[
    'word.postag='+word_pos_tag, # f1 is the PoS tag of the word
    'word.lower='+word.lower(), # f2 is input word is in lower case
    'word[-3:]='+word[-3:], # Last three characters
    'word[-2:]='+word[-2:], # Last two characters
    'word.isupper=%s' % word.isupper(), # is the word in all upper case
    'word.isdigit=%s' % word.isdigit(), # is the word a number
    'words.startsWithCapital=%s' %word[0].isupper() # is the word starting with capital letter
  ]
  if pos>0:
    prev_word=sentence[pos-1]
    for token in model(prev_word):
      prev_word_pos_tag=token.pos_
    features.extend([
      'prev_word.postag='+prev_word_pos_tag, # previous word PoS tag
      'prev_word.lower=' + prev_word.lower(), # previous word in lower case
      'prev_word.isupper=%s' % prev_word.isupper(), # is previous word in upper case
      'prev_word.isdigit=%s' % prev_word.isdigit(), # is previous word a number
      'prev_words.startsWithCapital=%s' % prev_word[0].isupper() # is previous word starting with capital letter
    ])
  else:
    features.append('BEG') # Beginning of sentence
  if (pos == len(sentence)-1):
    features.append('END') # End of sentence
  return features

# %% [markdown]
# # Getting the features

# %%
# Write a code to get features for a sentence.
def getFeaturesForOneSentence(sentence):
  sentence_list = sentence.split()
  return [getFeaturesForOneWord(sentence_list, pos) for pos in range(len(sentence_list))]

# %%
# Write a code to get the labels for a sentence.
def getLabelsInListForOneSentence(labels):
  return labels.split()

# %%
# Checking the workings of our feature on an example sentence from the trains set 
example_sentence = train_set[5] # Choosing 6th sentence
print(example_sentence) # Printing the entire sentence for reference

example_features = getFeaturesForOneSentence(example_sentence)
example_features[5] # Choosing the 6th word
# Out:
# Cesarean rates at tertiary care hospitals should be compared with rates at community hospitals only after correcting for dissimilar patient groups or gestational age
# ['word.postag=NOUN',
#  'word.lower=hospitals',
#  'word[-3:]=als',
#  'word[-2:]=ls',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'words.startsWithCapital=False',
#  'prev_word.postag=NOUN',
#  'prev_word.lower=care',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_words.startsWithCapital=False']

# %%
example_features[0] # first word
# Out:
# ['word.postag=ADJ',
#  'word.lower=cesarean',
#  'word[-3:]=ean',
#  'word[-2:]=an',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'words.startsWithCapital=True',
#  'BEG']

# %%
example_features[-1] # last word
# Out:
# ['word.postag=NOUN',
#  'word.lower=age',
#  'word[-3:]=age',
#  'word[-2:]=ge',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'words.startsWithCapital=False',
#  'prev_word.postag=ADJ',
#  'prev_word.lower=gestational',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_words.startsWithCapital=False',
#  'END']

# %% [markdown]
# # Define input and target variables

# %% [markdown]
# ### Define the features' values for each sentence as input variable for CRF model in test and the train dataset

# %%
X_train = [getFeaturesForOneSentence(sentence) for sentence in train_set]
Y_train = [getLabelsInListForOneSentence(labels) for labels in train_label]

# %% [markdown]
# ### Define the labels as the target variable for test and the train dataset

# %%
X_test = [getFeaturesForOneSentence(sentence) for sentence in test_set]
Y_test = [getLabelsInListForOneSentence(labels) for labels in test_label]

# %% [markdown]
# # Build the CRF Model

# %%
crf=sklearn_crfsuite.CRF(max_iterations=100)
try:
    crf.fit(X_train, Y_train)
except AttributeError:
    pass

# %% [markdown]
# # Model Evaluation

# %%
Y_pred=crf.predict(X_test)

# %% [markdown]
# # F1 Score

# %%
metrics.flat_f1_score(Y_test, Y_pred, average='weighted')
# Out:
# 0.9033383079953226

# %%
# Testing a sample prediction against actual values
# Print the orginal labels and predicted labels for the sentence  in test data, which is at index value 1002
id = 1002
print("Sentence:",test_set[id])
print("Orig Labels:", Y_test[id])
print("Pred Labels:", Y_pred[id])
# Out:
# Sentence: Gene therapy for myocardial angiogenesis
# Orig Labels: ['T', 'T', 'O', 'D', 'D']
# Pred Labels: ['T', 'T', 'O', 'O', 'O']

# %% [markdown]
# # As we can see, the record at 1002 sentence is a correct prediction.

# %%
# Creating dictionary out of the predicted labels from our model
dict={}
for count, labels in enumerate(Y_pred): # we are taking the Y-pred labels and count will have the record ID
    temp="".join(labels) # removing the spaces between the lablels
    #print(count, temp)
    totalD=len(re.findall('D',temp)) # find number of 'D' in the sentence
    totalT=len(re.findall('T',temp)) # find number of 'T' in the sentence
    if totalD>0 and totalT>0: # this means that the sentence has disease and treatment
        indexD=[];indexT=[];start_from=0 # Initializing variables used
        for i in range(totalD):
            foundat=temp.find('D',start_from) # search for 'D' from start_from in the labels
            indexD.append(foundat) # put the foundat index in a list called indexD
            start_from=foundat+1 # re-initialize start_from from the next word
        start_from=0 # initialize the same variable for 'T' labels now
        for i in range(totalT):
            foundat=temp.find('T',start_from) # search for 'T' from start_from in the labels
            indexT.append(foundat) # put the foundat index in a list called indexT
            start_from=foundat+1 # re-initialize start_from from the next word
        disease='' # Initialize the string disease with empty string
        for i in indexD: # Looping through the indexes where 'D' is located
            disease=disease+test_set[count].split()[i] # we are taking i-th word of the count which is index of sentence
            if i+1 not in indexD: # Check condition if the next word is also in the list
                disease=disease+', ' # this will be executed for a new disease
            else:
                disease=disease+' ' # this will be executed for continuation of disease name
        treatment='' # Initialize the string treatment with empty string
        for i in indexT: # Looping through the indexes where 'D' is located
            treatment=treatment+test_set[count].split()[i] # we are taking i-th word of the count which is index of sentence
            if i+1 not in indexT: # Check condition if the next word is also in the list
                treatment=treatment+', ' # this will be executed for a new treatment
            else:
                treatment=treatment+' ' # this will be executed for continuation of treatment
        # finally entering the disease and treatment in the dictionary after removing the last comma and space character
        dict[disease.rstrip(', ')]=treatment.rstrip(', ') 
            
dict
# Out:
# {'B16 melanoma': 'adenosine triphosphate and treatment, buthionine sulfoximine',
#  "Eisenmenger 's syndrome": 'laparoscopic cholecystectomy',
#  "Parkinson 's disease": 'Microelectrode-guided posteroventral pallidotomy',
#  "abdominal tuberculosis, Crohn 's disease": 'steroids',
#  'acute cerebral ischemia': 'Antiplatelet therapy',
#  'acute myocardial infarction': 'Thrombolytic therapy',
#  'acute occlusion of the middle cerebral artery, large embolus or high-grade stenosis': 'thrombolytic therapy',
#  'advanced nsclc assessing': 'combination chemotherapy of cisplatin , ifosfamide and irinotecan with rhg-csf support',
#  'advanced rectal cancer': 'Nerve-sparing surgery',
#  'advanced renal cell carcinoma': 'various interferon alpha preparations, interferon alfa-N1 , interferon alfa-2a',
#  'advanced stage ( TNM IIB-IVB ) mycosis fungoides': 'a combination chemotherapy program consisting of bleomycin and methotrexate weekly , doxorubicin',
#  'asthma': 'several inhaled corticosteroids',
#  'autoimmune hemolytic anemia': 'heparin',
#  'benign prostatic hyperplasia': 'conservative pharmacological treatment',
#  'biliary dyskinesia': 'Cholecystectomy, first-line therapy',
#  'breast cancer': 'undergone subcutaneous mastectomy',
#  'bronchiectasis': 'Current surgical therapy',
#  'cancer': 'oral drugs, chemotherapy',
#  'cellulitis': 'G-CSF therapy, intravenous antibiotic treatment',
#  'cerebral palsy': 'Hyperbaric oxygen therapy',
#  'chronic hepatitis C': 'Combination therapy with interferon-alpha ( IFN alpha ) plus Ribavirin',
#  'colorectal cancer': 'docosahexanoic acid ( DHA ) -concentrated fish oil',
#  'colorectal metastases': 'therapeutic vats metastasectomy',
#  'coronary-artery disease': 'Antichlamydial antibiotics',
#  'disseminated malignant melanoma': 'leukocyte A recombinant interferon ( rIFN-alpha',
#  'duodenogastric reflux': 'cholecystectomy',
#  "early Parkinson 's disease": 'Ropinirole monotherapy',
#  'epithelial ovarian cancer': 'High-dose chemotherapy',
#  'esophageal achalasia': 'botulinum toxin injection , pneumatic dilation , and laparoscopic myotomy',
#  'female stress urinary incontinence': 'surgical treatment',
#  'foot infection': 'G-CSF treatment',
#  'head and neck cancer': 'irradiation therapy, intravenous amifostine',
#  'hepatic metastases from colorectal cancer': 'Hepatic arterial infusion of chemotherapy',
#  'hepatitis C viremia': 'combination therapy',
#  'hereditary retinoblastoma': 'radiotherapy',
#  'infection': 'antileukemic therapy',
#  'inflammatory skin diseases': 'topical corticosteroids',
#  'inoperable advanced malignancies such as colorectal cancer': 'combination with leucovorin or cisplatin',
#  'limited stage small cell lung cancer': 'vip combination chemotherapy',
#  'limited-stage small-cell carcinoma': 'combined-modality therapy',
#  'locally advanced non-small-cell lung cancer ( la-nsclc )': 'chemotherapy and radiotherapy )',
#  "low-grade non-Hodgkin 's lymphoma": 'interferon alpha',
#  'lung carcinoma': 'videothoracoscopic lobectomy or partial resection, open thoracotomy',
#  'major pulmonary embolism': 'Thrombolytic treatment, right-side hemodynamics',
#  'malignant pleural effusions from nsclc': 'systemic chemotherapy',
#  'malignant pleural mesothelioma': 'thoracotomy , radiotherapy , and chemotherapy',
#  'melanoma, ovarian carcinoma brain metastasis': 'surgical resection',
#  'metastatic colorectal cancer': 'intravenous oxaliplatin',
#  'mitomycin-resistant bladder cancer': 'photodynamic therapy in combination with mitomycin C',
#  'multiple sclerosis': 'Intravenous immunoglobulin treatment',
#  'neutropenia': 'cancer chemotherapy',
#  "non-hodgkin 's lymphoma , breast cancer, mesothelioma and non-small cell lung cancer": 'oxaliplatin',
#  'non-obstructive azoospermia': 'testicular fine needle aspiration ( TEFNA ), open biopsy and testicular sperm extraction ( TESE )',
#  'non-small cell lung cancer, advanced hormone refractory prostate cancer': 'combination with paclitaxel and carboplatin, combination with mitoxantrone',
#  'non-small-cell-lung-cancer ( nsclc )': 'cisplatin and radiotherapy',
#  'nonimmune hydrops fetalis': 'Trisomy',
#  'novel hepatitis B': 'vaccine containing MF59',
#  'nsclc': 'evaluate planned sequential chemotherapy',
#  'nsclc, nsclc ( stage iiib ), sclc': 'got surgical treatment, radiotherapy',
#  'partial seizures': 'lamotrigine monotherapy',
#  'pathologic stage i non-small cell lung cancer': 'postoperative oral administration',
#  'persistent asthma': 'Contemporary asthma management guidelines list inhaled corticosteroids',
#  'phaeochromocytoma': 'Adrenalectomy',
#  'platinum-pretreated ovarian cancer': 'oxaliplatin',
#  'postvitrectomy diabetic vitreous hemorrhage': 'Peripheral retinal cryotherapy',
#  'preeclampsia ( proteinuric hypertension )': 'intrauterine insemination, intrauterine insemination',
#  'primary cancer': 'Immunotherapy',
#  'primary lung cancer, adenocarcinoma, squamous cell carcinoma': 'resection',
#  'primary pulmonary hypertension ( PPH )': 'fenfluramines',
#  'primary sclerosing cholangitis ( PSC )': 'oral budesonide',
#  'primary uveal melanoma': 'transpupillary thermotherapy',
#  'prostate cancer': 'radical prostatectomy and iodine 125 interstitial radiotherapy',
#  'proximal hypospadias': 'Tubularized incised plate hypospadias repair',
#  'pulmonary symptoms': 'chemotherapy',
#  'radiation-induced myelopathy': 'heparin and enoxaparin',
#  'renal cell carcinoma': 'Interferon treatment',
#  'rhinovirus': 'clarithromycin',
#  'sclc': 'tumor vaccines',
#  'sclc, limited disease, extensive disease': 'platinum dose ( cisplatin plus carboplatin ) in combination chemotherapy, combination therapy with carboplatin alone',
#  'severe acquired hyperammonemia, cancer': 'organ transplantation and chemotherapy',
#  'severe hypoxemia': 'glucocorticoid pulse therapy',
#  'severe secondary peritonitis': 'Surgical management',
#  'small cell lung cancer': 'prophylactic cranial irradiation prolongs',
#  'small-cell lung cancer': 'paclitaxel plus carboplatin ( pc ), vinorelbine plus cisplatin',
#  'soft tissue sarcomas': 'Radiotherapy',
#  'spinal adhesive arachnoiditis': 'Surgical management',
#  'stage 0 lung carcinoma': 'curative therapy',
#  'stage iii nsclc': 'chemotherapy, surgery',
#  'stress urinary incontinence': 'therapy',
#  'supraclavicular node metastases in nsclc': 'chemoradiotherapy',
#  'symptoms of a common cold': 'Macrolide antibiotics',
#  'temporomandibular joint arthropathy': 'arthroscopic treatment',
#  'the common cold': 'pseudoephedrine plus acetaminophen',
#  'treating stress urinary incontinence': 'surgical procedures',
#  'tumors': 'Immunotherapy',
#  'unresectable stage iii nsclc': 'studies involving sequential chemotherapy',
#  'unstable angina or non-Q-wave myocardial infarction': 'roxithromycin',
#  'untreated small cell lung cancer ( sclc ), untreated sclc': 'chemotherapy',
#  'ventricular tachycardia': 'Guiding surgical therapy'}

# %%
# Creating dataframe out of the dictionary of disease and treatment
df1=pd.DataFrame(dict.items(),columns=['disease','treatment'])
df1.head(10)
# Out:
#                                              disease  \
# 0                          nonimmune hydrops fetalis
# 1                          hereditary retinoblastoma
# 2  unstable angina or non-Q-wave myocardial infar...
# 3                            coronary-artery disease
# 4             primary pulmonary hypertension ( PPH )
# 5                                         cellulitis
# 6                                     foot infection
# 7                         early Parkinson 's disease
# 8           abdominal tuberculosis, Crohn 's disease
# 9               treating stress urinary incontinence
#
#                                          treatment
# 0                                          Trisomy
# 1                                     radiotherapy
# 2                                    roxithromycin
# 3                       Antichlamydial antibiotics
# 4                                    fenfluramines
# 5  G-CSF therapy, intravenous antibiotic treatment
# 6                                  G-CSF treatment
# 7                           Ropinirole monotherapy
# 8                                         steroids
# 9                              surgical procedures

# %% [markdown]
# # Predict the treatment for the disease name: 'hereditary retinoblastoma'

# %%
dict['hereditary retinoblastoma']
# Out:
# 'radiotherapy'

# %% [markdown]
# ### End of Assignment
